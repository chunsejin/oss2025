# %% [markdown]
# <a href="https://colab.research.google.com/github/Seungu-oss/oss2025/blob/main/%EB%8C%80%EB%A5%99%EB%B3%84_1%EC%9D%B8%EB%8B%B9_gdp_boxplot%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#read
data = pd.read_csv("/content/sample_data/WHI_Inflation.csv",delimiter="\t")
data.head(10)
df = pd.read_csv(file_path, delimiter='\t', encoding='ascii')
# Box Plot for Distribution of GDP per Capita by Continent
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Continent', y='GDP per Capita', order=df['Continent'].value_counts().index)
plt.title('GDP per Capita Distribution by Continent')
plt.xticks(rotation=45)
plt.show()
